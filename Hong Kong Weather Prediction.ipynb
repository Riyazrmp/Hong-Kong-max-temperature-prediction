# %%
import pandas as pd
weather = pd.read_csv("weather.csv",index_col="date")

# %%
weather
# Out:
#           mean_temp Grass_Min_Temp  max_Temp  mean_amount_of_cloud  \
# date
# 1/1/70         17.7           12.4      20.7                  32.0
# 1/2/70         19.5           12.8      22.9                  44.0
# 1/3/70         18.8           14.7      21.2                  35.0
# 1/4/70         17.9           13.8      20.7                  20.0
# 1/5/70         14.7           13.1      18.2                  66.0
# ...             ...            ...       ...                   ...
# 12/27/19       18.0           13.5      21.3                  23.0
# 12/28/19       18.5           14.9      20.9                  64.0
# 12/29/19       18.8           16.9      19.6                  92.0
# 12/30/19       20.3           18.7      22.5                  90.0
# 12/31/19       19.2           18.5      20.2                  93.0
#
#           mean_dew_point_temp  mean_wet_bulb_temp  min_temp  pressure  \
# date
# 1/1/70                   13.4                15.2      15.5    1018.7
# ...

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#           mean_temp grass_min_temp  max_temp  mean_amount_of_cloud  \
# date
# 1/1/70         17.7           12.4      20.7                  32.0
# 1/2/70         19.5           12.8      22.9                  44.0
# 1/3/70         18.8           14.7      21.2                  35.0
# 1/4/70         17.9           13.8      20.7                  20.0
# 1/5/70         14.7           13.1      18.2                  66.0
# ...             ...            ...       ...                   ...
# 12/27/19       18.0           13.5      21.3                  23.0
# 12/28/19       18.5           14.9      20.9                  64.0
# 12/29/19       18.8           16.9      19.6                  92.0
# 12/30/19       20.3           18.7      22.5                  90.0
# 12/31/19       19.2           18.5      20.2                  93.0
#
#           mean_dew_point_temp  mean_wet_bulb_temp  min_temp  pressure  \
# date
# 1/1/70                   13.4                15.2      15.5    1018.7
# ...

# %%
weather.apply(pd.isnull).sum()
# Out:
# mean_temp               338
# grass_min_temp          338
# max_temp                338
# mean_amount_of_cloud    338
# mean_dew_point_temp     338
# mean_wet_bulb_temp      338
# min_temp                338
# pressure                338
# rainfall                338
# rh                      338
# dtype: int64

# %%
weather = weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# mean_temp               0
# grass_min_temp          0
# max_temp                0
# mean_amount_of_cloud    0
# mean_dew_point_temp     0
# mean_wet_bulb_temp      0
# min_temp                0
# pressure                0
# rainfall                0
# rh                      0
# dtype: int64

# %%
weather.dtypes
# Out:
# mean_temp               float64
# grass_min_temp           object
# max_temp                float64
# mean_amount_of_cloud    float64
# mean_dew_point_temp     float64
# mean_wet_bulb_temp      float64
# min_temp                float64
# pressure                float64
# rainfall                 object
# rh                      float64
# dtype: object

# %%
weather.index
# Out:
# Index([  '1/1/70',   '1/2/70',   '1/3/70',   '1/4/70',   '1/5/70',   '1/6/70',
#          '1/7/70',   '1/8/70',   '1/9/70',  '1/10/70',
#        ...
#        '12/22/19', '12/23/19', '12/24/19', '12/25/19', '12/26/19', '12/27/19',
#        '12/28/19', '12/29/19', '12/30/19', '12/31/19'],
#       dtype='object', name='date', length=18600)

# %%
weather.index = pd.to_datetime(weather.index)
# Out:
# /var/folders/hs/3zv1hlhs1h90kf73kmyl10rc0000gp/T/ipykernel_8964/3965993623.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   weather.index = pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['2070-01-01', '2070-01-02', '2070-01-03', '2070-01-04',
#                '2070-01-05', '2070-01-06', '2070-01-07', '2070-01-08',
#                '2070-01-09', '2070-01-10',
#                ...
#                '2019-12-22', '2019-12-23', '2019-12-24', '2019-12-25',
#                '2019-12-26', '2019-12-27', '2019-12-28', '2019-12-29',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', name='date', length=18600, freq=None)

# %%
weather
# Out:
#             mean_temp grass_min_temp  max_temp  mean_amount_of_cloud  \
# date
# 2070-01-01       17.7           12.4      20.7                  32.0
# 2070-01-02       19.5           12.8      22.9                  44.0
# 2070-01-03       18.8           14.7      21.2                  35.0
# 2070-01-04       17.9           13.8      20.7                  20.0
# 2070-01-05       14.7           13.1      18.2                  66.0
# ...               ...            ...       ...                   ...
# 2019-12-27       18.0           13.5      21.3                  23.0
# 2019-12-28       18.5           14.9      20.9                  64.0
# 2019-12-29       18.8           16.9      19.6                  92.0
# 2019-12-30       20.3           18.7      22.5                  90.0
# 2019-12-31       19.2           18.5      20.2                  93.0
#
#             mean_dew_point_temp  mean_wet_bulb_temp  min_temp  pressure  \
# date
# ...

# %%
weather.index.year
# Out:
# Index([2070.0, 2070.0, 2070.0, 2070.0, 2070.0, 2070.0, 2070.0, 2070.0, 2070.0,
#        2070.0,
#        ...
#        2019.0, 2019.0, 2019.0, 2019.0, 2019.0, 2019.0, 2019.0, 2019.0, 2019.0,
#        2019.0],
#       dtype='float64', name='date', length=18600)

# %%
weather.index.value_counts().sort_index()
# Out:
# date
# 1974-01-01    1
# 1974-01-02    1
# 1974-01-03    1
# 1974-01-04    1
# 1974-01-05    1
#              ..
# 2073-12-27    1
# 2073-12-28    1
# 2073-12-29    1
# 2073-12-30    1
# 2073-12-31    1
# Name: count, Length: 18262, dtype: int64

# %%
weather.index.year.value_counts().sort_index()
# Out:
# date
# 1974.0    365
# 1975.0    365
# 1976.0    366
# 1977.0    365
# 1978.0    365
# 1979.0    365
# 1980.0    366
# 1981.0    365
# 1982.0    365
# 1983.0    365
# 1984.0    366
# 1985.0    365
# 1986.0    365
# 1987.0    365
# 1988.0    366
# 1989.0    365
# 1990.0    365
# 1991.0    365
# 1992.0    366
# 1993.0    365
# 1994.0    365
# 1995.0    365
# 1996.0    366
# 1997.0    365
# 1998.0    365
# 1999.0    365
# 2000.0    366
# 2001.0    365
# 2002.0    365
# 2003.0    365
# 2004.0    366
# 2005.0    365
# 2006.0    365
# 2007.0    365
# 2008.0    366
# 2009.0    365
# 2010.0    365
# 2011.0    365
# 2012.0    366
# 2013.0    365
# 2014.0    365
# 2015.0    365
# 2016.0    366
# 2017.0    365
# 2018.0    365
# 2019.0    365
# 2070.0    365
# 2071.0    365
# 2072.0    366
# 2073.0    365
# Name: count, dtype: int64

# %%
weather["mean_temp"].plot()
# Out:
# <Axes: xlabel='date'>

# %%
weather.drop('2070')
# Out:
#             mean_temp grass_min_temp  max_temp  mean_amount_of_cloud  \
# date
# 2070-01-02       19.5           12.8      22.9                  44.0
# 2070-01-03       18.8           14.7      21.2                  35.0
# 2070-01-04       17.9           13.8      20.7                  20.0
# 2070-01-05       14.7           13.1      18.2                  66.0
# 2070-01-06       13.8            9.5      16.9                  63.0
# ...               ...            ...       ...                   ...
# 2019-12-27       18.0           13.5      21.3                  23.0
# 2019-12-28       18.5           14.9      20.9                  64.0
# 2019-12-29       18.8           16.9      19.6                  92.0
# 2019-12-30       20.3           18.7      22.5                  90.0
# 2019-12-31       19.2           18.5      20.2                  93.0
#
#             mean_dew_point_temp  mean_wet_bulb_temp  min_temp  pressure  \
# date
# ...

# %%
weather.index.year.value_counts().sort_index()
# Out:
# date
# 1974.0    365
# 1975.0    365
# 1976.0    366
# 1977.0    365
# 1978.0    365
# 1979.0    365
# 1980.0    366
# 1981.0    365
# 1982.0    365
# 1983.0    365
# 1984.0    366
# 1985.0    365
# 1986.0    365
# 1987.0    365
# 1988.0    366
# 1989.0    365
# 1990.0    365
# 1991.0    365
# 1992.0    366
# 1993.0    365
# 1994.0    365
# 1995.0    365
# 1996.0    366
# 1997.0    365
# 1998.0    365
# 1999.0    365
# 2000.0    366
# 2001.0    365
# 2002.0    365
# 2003.0    365
# 2004.0    366
# 2005.0    365
# 2006.0    365
# 2007.0    365
# 2008.0    366
# 2009.0    365
# 2010.0    365
# 2011.0    365
# 2012.0    366
# 2013.0    365
# 2014.0    365
# 2015.0    365
# 2016.0    366
# 2017.0    365
# 2018.0    365
# 2019.0    365
# 2070.0    365
# 2071.0    365
# 2072.0    366
# 2073.0    365
# Name: count, dtype: int64

# %%
weather["target"] = weather.shift(-1)["max_temp"]

# %%
weather
# Out:
#             mean_temp grass_min_temp  max_temp  mean_amount_of_cloud  \
# date
# 2070-01-01       17.7           12.4      20.7                  32.0
# 2070-01-02       19.5           12.8      22.9                  44.0
# 2070-01-03       18.8           14.7      21.2                  35.0
# 2070-01-04       17.9           13.8      20.7                  20.0
# 2070-01-05       14.7           13.1      18.2                  66.0
# ...               ...            ...       ...                   ...
# 2019-12-27       18.0           13.5      21.3                  23.0
# 2019-12-28       18.5           14.9      20.9                  64.0
# 2019-12-29       18.8           16.9      19.6                  92.0
# 2019-12-30       20.3           18.7      22.5                  90.0
# 2019-12-31       19.2           18.5      20.2                  93.0
#
#             mean_dew_point_temp  mean_wet_bulb_temp  min_temp  pressure  \
# date
# ...

# %%
weather = weather.ffill()

# %%
weather
# Out:
#             mean_temp grass_min_temp  max_temp  mean_amount_of_cloud  \
# date
# 2070-01-01       17.7           12.4      20.7                  32.0
# 2070-01-02       19.5           12.8      22.9                  44.0
# 2070-01-03       18.8           14.7      21.2                  35.0
# 2070-01-04       17.9           13.8      20.7                  20.0
# 2070-01-05       14.7           13.1      18.2                  66.0
# ...               ...            ...       ...                   ...
# 2019-12-27       18.0           13.5      21.3                  23.0
# 2019-12-28       18.5           14.9      20.9                  64.0
# 2019-12-29       18.8           16.9      19.6                  92.0
# 2019-12-30       20.3           18.7      22.5                  90.0
# 2019-12-31       19.2           18.5      20.2                  93.0
#
#             mean_dew_point_temp  mean_wet_bulb_temp  min_temp  pressure  \
# date
# ...

# %%
from sklearn.linear_model import Ridge

# %%
pip install scikit-learn

# %%
from sklearn.linear_model import Ridge

# %%
weather.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 weather.corr()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
from sklearn.linear_model import Ridge

# %%
from sklearn.linear_model import ridge

# %%
from sklearn.linear_model import Ridge
rr = Ridge(alpha=.1)

# %%
weather.dtypes
# Out:
# mean_temp               float64
# grass_min_temp           object
# max_temp                float64
# mean_amount_of_cloud    float64
# mean_dew_point_temp     float64
# mean_wet_bulb_temp      float64
# min_temp                float64
# pressure                float64
# rainfall                 object
# rh                      float64
# target                  float64
# dtype: object

# %%
weather["grass_min_temp"] = pd.to_numeric(weather["grass_min_temp"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2280, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "***"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 weather["grass_min_temp"] = pd.to_numeric(weather["grass_min_temp"])
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/tools/numeric.py:217, in to_numeric(arg, errors, downcast, dtype_backend)
#     215 coerce_numeric = errors not in ("ignore", "raise")
#     216 try:
# --> 217     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa
#     218         values,
#     219         set(),
#     220         coerce_numeric=coerce_numeric,
# ...

# %%
weather["grass_min_temp"].replace('***', '0', inplace=True)

# %%
weather["grass_min_temp"] = pd.to_numeric(weather["grass_min_temp"])

# %%
weather.dtypes
# Out:
# mean_temp               float64
# grass_min_temp          float64
# max_temp                float64
# mean_amount_of_cloud    float64
# mean_dew_point_temp     float64
# mean_wet_bulb_temp      float64
# min_temp                float64
# pressure                float64
# rainfall                 object
# rh                      float64
# target                  float64
# dtype: object

# %%
weather
# Out:
#             mean_temp  grass_min_temp  max_temp  mean_amount_of_cloud  \
# date
# 2070-01-01       17.7            12.4      20.7                  32.0
# 2070-01-02       19.5            12.8      22.9                  44.0
# 2070-01-03       18.8            14.7      21.2                  35.0
# 2070-01-04       17.9            13.8      20.7                  20.0
# 2070-01-05       14.7            13.1      18.2                  66.0
# ...               ...             ...       ...                   ...
# 2019-12-27       18.0            13.5      21.3                  23.0
# 2019-12-28       18.5            14.9      20.9                  64.0
# 2019-12-29       18.8            16.9      19.6                  92.0
# 2019-12-30       20.3            18.7      22.5                  90.0
# 2019-12-31       19.2            18.5      20.2                  93.0
#
#             mean_dew_point_temp  mean_wet_bulb_temp  min_temp  pressure  \
# date
# ...

# %%
weather["rh"].replace('Trace', '0', inplace=True)

# %%
weather["rh"] = pd.to_numeric(weather["rh"])

# %%
weather.dtypes
# Out:
# mean_temp               float64
# grass_min_temp          float64
# max_temp                float64
# mean_amount_of_cloud    float64
# mean_dew_point_temp     float64
# mean_wet_bulb_temp      float64
# min_temp                float64
# pressure                float64
# rainfall                 object
# rh                      float64
# target                  float64
# dtype: object

# %%
weather
# Out:
#             mean_temp  grass_min_temp  max_temp  mean_amount_of_cloud  \
# date
# 2070-01-01       17.7            12.4      20.7                  32.0
# 2070-01-02       19.5            12.8      22.9                  44.0
# 2070-01-03       18.8            14.7      21.2                  35.0
# 2070-01-04       17.9            13.8      20.7                  20.0
# 2070-01-05       14.7            13.1      18.2                  66.0
# ...               ...             ...       ...                   ...
# 2019-12-27       18.0            13.5      21.3                  23.0
# 2019-12-28       18.5            14.9      20.9                  64.0
# 2019-12-29       18.8            16.9      19.6                  92.0
# 2019-12-30       20.3            18.7      22.5                  90.0
# 2019-12-31       19.2            18.5      20.2                  93.0
#
#             mean_dew_point_temp  mean_wet_bulb_temp  min_temp  pressure  \
# date
# ...

# %%
weather["rainfall"] = pd.to_numeric(weather["rainfall"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2280, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Trace"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 weather["rainfall"] = pd.to_numeric(weather["rainfall"])
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/tools/numeric.py:217, in to_numeric(arg, errors, downcast, dtype_backend)
#     215 coerce_numeric = errors not in ("ignore", "raise")
#     216 try:
# --> 217     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa
#     218         values,
#     219         set(),
#     220         coerce_numeric=coerce_numeric,
# ...

# %%
weather["rainfall"].replace('Trace', '0', inplace=True)

# %%
weather["rainfall"] = pd.to_numeric(weather["rainfall"])

# %%
weather
# Out:
#             mean_temp  grass_min_temp  max_temp  mean_amount_of_cloud  \
# date
# 2070-01-01       17.7            12.4      20.7                  32.0
# 2070-01-02       19.5            12.8      22.9                  44.0
# 2070-01-03       18.8            14.7      21.2                  35.0
# 2070-01-04       17.9            13.8      20.7                  20.0
# 2070-01-05       14.7            13.1      18.2                  66.0
# ...               ...             ...       ...                   ...
# 2019-12-27       18.0            13.5      21.3                  23.0
# 2019-12-28       18.5            14.9      20.9                  64.0
# 2019-12-29       18.8            16.9      19.6                  92.0
# 2019-12-30       20.3            18.7      22.5                  90.0
# 2019-12-31       19.2            18.5      20.2                  93.0
#
#             mean_dew_point_temp  mean_wet_bulb_temp  min_temp  pressure  \
# date
# ...

# %%
weather.dtypes
# Out:
# mean_temp               float64
# grass_min_temp          float64
# max_temp                float64
# mean_amount_of_cloud    float64
# mean_dew_point_temp     float64
# mean_wet_bulb_temp      float64
# min_temp                float64
# pressure                float64
# rainfall                float64
# rh                      float64
# target                  float64
# dtype: object

# %%
predictors = weather.columns[~weather.columns.isin(["target"])]

# %%
predictors
# Out:
# Index(['mean_temp', 'grass_min_temp', 'max_temp', 'mean_amount_of_cloud',
#        'mean_dew_point_temp', 'mean_wet_bulb_temp', 'min_temp', 'pressure',
#        'rainfall', 'rh'],
#       dtype='object')

# %%
weather.corr()
# Out:
#                       mean_temp  grass_min_temp  max_temp  \
# mean_temp              1.000000        0.919901  0.984256
# grass_min_temp         0.919901        1.000000  0.879700
# max_temp               0.984256        0.879700  1.000000
# mean_amount_of_cloud   0.003393        0.209164 -0.084570
# mean_dew_point_temp    0.924494        0.918316  0.885025
# mean_wet_bulb_temp     0.972725        0.936194  0.942117
# min_temp               0.989638        0.930539  0.957551
# pressure              -0.825911       -0.810648 -0.797106
# rainfall               0.119641        0.173126  0.093954
# rh                     0.255809        0.408805  0.188687
# target                 0.939746        0.843993  0.931416
#
#                       mean_amount_of_cloud  mean_dew_point_temp  \
# mean_temp                         0.003393             0.924494
# grass_min_temp                    0.209164             0.918316
# max_temp                         -0.084570             0.885025
# ...

# %%
def bt(weather,model, predictors, s = 3650, step = 90):
    all_p = []
    for i in range(s,weather.shape[0],step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]
        model.fit(train[predictors],train["target"])
        preds = model.predict(test[predictors])
        preds = pd.Series(preds,index = test.index)
        combined = pd.concat([test["target"],preds],axis=1)
        combined.columns = ["actual","prediction"]
        combined["diff"] = (combined["prediction"]-combined["actual"]).abs()
        all_p.append(combined)
    return pd.concat(all_p)

# %%
predictions = bt(weather, rr,predictors)

# %%
predictions
# Out:
#             actual  prediction      diff
# date
# 1979-10-24    26.9   26.958126  0.058126
# 1979-10-25    27.5   27.204420  0.295580
# 1979-10-26    27.2   27.159013  0.040987
# 1979-10-27    27.9   27.389765  0.510235
# 1979-10-28    29.9   28.093431  1.806569
# ...            ...         ...       ...
# 2019-12-27    20.9   21.217398  0.317398
# 2019-12-28    19.6   21.087063  1.487063
# 2019-12-29    22.5   21.028172  1.471828
# 2019-12-30    20.2   22.449022  2.249022
# 2019-12-31    20.2   21.010774  0.810774
#
# [14950 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(predictions["actual"],predictions["prediction"])
# Out:
# 1.3829774350886508

# %%
weather
# Out:
#             mean_temp  grass_min_temp  max_temp  mean_amount_of_cloud  \
# date
# 2070-01-01       17.7            12.4      20.7                  32.0
# 2070-01-02       19.5            12.8      22.9                  44.0
# 2070-01-03       18.8            14.7      21.2                  35.0
# 2070-01-04       17.9            13.8      20.7                  20.0
# 2070-01-05       14.7            13.1      18.2                  66.0
# ...               ...             ...       ...                   ...
# 2019-12-27       18.0            13.5      21.3                  23.0
# 2019-12-28       18.5            14.9      20.9                  64.0
# 2019-12-29       18.8            16.9      19.6                  92.0
# 2019-12-30       20.3            18.7      22.5                  90.0
# 2019-12-31       19.2            18.5      20.2                  93.0
#
#             mean_dew_point_temp  mean_wet_bulb_temp  min_temp  pressure  \
# date
# ...

# %%
rr.predict([[17.4,12.4,20.7,32,13.2,15.2,15.5,1018.7,0,77]])
# Out:
# /Users/riyaz/anaconda3/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(
# array([20.93949646])

# %%
rr.predict([[20.3,18.7,22.5,90,18.7,19.3,18.8,1020,0.3,91]])
# Out:
# /Users/riyaz/anaconda3/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(
# array([22.44902193])

# %%
import pickle

# %%
data = {"model":rr}
with open('WeatherRidgeModel.pkl','wb') as file:
    pickle.dump(data,file)
